# %% [markdown]
# # Python Source Library

# %% [markdown]
# ## Importing Python source files
#
# [httpimport](https://github.com/operatorequals/httpimport)

# %%
import httpimport

with httpimport.github_repo('jckantor', 'cbe-virtual-laboratory',):
    import src

# %%
a = httpimport.load('src', 'https://github.com/jckantor/cbe-virtual-laboratory/blob/main')

# %%
a.add()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-fddc01c87ea9> in <module>()
# ----> 1 a.add()
#
# AttributeError: module 'src' has no attribute 'add'

# %%
src.add
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-a64c5a4201ed> in <module>()
# ----> 1 src.add
#
# AttributeError: module 'src' has no attribute 'add'

# %%
with httpimport.github_repo('operatorequals', 'covertutils', branch = 'master'):
    import covertutils

# %%
coverutils?
# Out:
# Object `coverutils` not found.
