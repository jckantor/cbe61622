# %% [markdown]
# # Python Source Library

# %% [markdown]
# ## Importing Python source files
#
# [httpimport](https://github.com/operatorequals/httpimport)

# %%
import httpimport

with httpimport.remote_repo('src', 'https://github.com/jckantor/cbe-virtual-laboratory/'):
    import add
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-0e51e0e209c9> in <module>()
#       2
#       3 with httpimport.remote_repo('src', 'https://github.com/jckantor/cbe-virtual-laboratory/'):
# ----> 4     import add
#
# ModuleNotFoundError: No module named 'add'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
