# %% [markdown]
# # Python Source Library

# %% [markdown]
# ## Importing Python source files
#
# [httpimport](https://github.com/operatorequals/httpimport)

# %%
import httpimport

with httpimport.github_repo('jckantor', 'cbe-virtual-laboratory', branch='master'):
    from src import hello
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-7bb4e631c292> in <module>()
#       2
#       3 with httpimport.github_repo('jckantor', 'cbe-virtual-laboratory', branch='master'):
# ----> 4     from src import hello
#
# ModuleNotFoundError: No module named 'src'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
