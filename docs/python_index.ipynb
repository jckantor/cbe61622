# %% [markdown]
# # [cbe61622](https://jckantor.github.io/cbe61622)
#
# ## Index of Python Libraries used in this Repository
#
# ### asyncio
# * [A.4.2 Asyncio](https://jckantor.github.io/cbe61622/A.04-Scheduling-Real-Time-Events-with-Simpy.html#A.4.2-Asyncio)
#
# ### cv2
# * [8.5.1.4 Capture to numpy array](https://jckantor.github.io/cbe61622/08.05-rpi-picamera_test.html#8.5.1.4-Capture-to-numpy-array)
# * [10.11.1.1 Python Imports](https://jckantor.github.io/cbe61622/10.11-Computer-Vision-Experiments.html#10.11.1.1-Python-Imports)
# * [10.11.2 Particle Labeling Classes](https://jckantor.github.io/cbe61622/10.11-Computer-Vision-Experiments.html#10.11.2-Particle-Labeling-Classes)
# * [10.12.1.1 Labeler Class](https://jckantor.github.io/cbe61622/10.12-Computer-Vision-Development.html#10.12.1.1-Labeler-Class)
# * [10.12.1.2 Loading image files](https://jckantor.github.io/cbe61622/10.12-Computer-Vision-Development.html#10.12.1.2-Loading-image-files)
# * [10.12.1.3 Image Rescaling and Cropping](https://jckantor.github.io/cbe61622/10.12-Computer-Vision-Development.html#10.12.1.3-Image-Rescaling-and-Cropping)
# * [10.12.1.5 Integrating Channels into Labeler](https://jckantor.github.io/cbe61622/10.12-Computer-Vision-Development.html#10.12.1.5-Integrating-Channels-into-Labeler)
# * [10.12.3 Classes](https://jckantor.github.io/cbe61622/10.12-Computer-Vision-Development.html#10.12.3-Classes)
# * [10.13.1 Application](https://jckantor.github.io/cbe61622/10.13-Computer-Vision-Application.html#10.13.1-Application)
#
# ### getpass
# * [7.1.1.4 Select a device](https://jckantor.github.io/cbe61622/07.01-Communicating _via_TCP.html#7.1.1.4-Select-a-device)
# * [7.2.1.3 Login to Particle](https://jckantor.github.io/cbe61622/07.02-Stepper_Motor_Control_via_I2C.html#7.2.1.3-Login-to-Particle)
# * [B.1.2 Login to Particle](https://jckantor.github.io/cbe61622/B.01-Particle_CLI.html#B.1.2-Login-to-Particle)
# * [B.2.2 Login to Particle](https://jckantor.github.io/cbe61622/B.02-Particle_Coding.html#B.2.2-Login-to-Particle)
# * [B.3.1.3 Login to Particle](https://jckantor.github.io/cbe61622/B.03-Particle-CLI.html#B.3.1.3-Login-to-Particle)
# * [B.4.1.3 Login to Particle](https://jckantor.github.io/cbe61622/B.04-Ultrasonic_Distance_Ranger.html#B.4.1.3-Login-to-Particle)
# * [B.5.1.3 Login to Particle](https://jckantor.github.io/cbe61622/B.05-Simple_Stop_Watch_using_Interrupts.html#B.5.1.3-Login-to-Particle)
#
# ### glob
# * [10.12.1.1 Labeler Class](https://jckantor.github.io/cbe61622/10.12-Computer-Vision-Development.html#10.12.1.1-Labeler-Class)
# * [10.12.1.1 Labeler Class](https://jckantor.github.io/cbe61622/10.12-Computer-Vision-Development.html#10.12.1.1-Labeler-Class)
# * [10.12.1.2 Loading image files](https://jckantor.github.io/cbe61622/10.12-Computer-Vision-Development.html#10.12.1.2-Loading-image-files)
# * [10.12.1.3 Image Rescaling and Cropping](https://jckantor.github.io/cbe61622/10.12-Computer-Vision-Development.html#10.12.1.3-Image-Rescaling-and-Cropping)
# * [10.12.1.5 Integrating Channels into Labeler](https://jckantor.github.io/cbe61622/10.12-Computer-Vision-Development.html#10.12.1.5-Integrating-Channels-into-Labeler)
# * [10.13.2 Demonstrations](https://jckantor.github.io/cbe61622/10.13-Computer-Vision-Application.html#10.13.2-Demonstrations)
#
# ### hello_world
# * [A.2.1 Method 1. Downloading individual Python files with wget](https://jckantor.github.io/cbe61622/A.02-Downloading_Python_source_files_from_github.html#A.2.1-Method-1.-Downloading-individual-Python-files-with-wget)
# * [A.2.2 Method 2. Cloning a git repository](https://jckantor.github.io/cbe61622/A.02-Downloading_Python_source_files_from_github.html#A.2.2-Method-2.-Cloning-a-git-repository)
#
# ### importlib
# * [A.2.1 Method 1. Downloading individual Python files with wget](https://jckantor.github.io/cbe61622/A.02-Downloading_Python_source_files_from_github.html#A.2.1-Method-1.-Downloading-individual-Python-files-with-wget)
# * [A.2.2 Method 2. Cloning a git repository](https://jckantor.github.io/cbe61622/A.02-Downloading_Python_source_files_from_github.html#A.2.2-Method-2.-Cloning-a-git-repository)
#
# ### json
# * [9.1.3 Version 1](https://jckantor.github.io/cbe61622/09.01-Publishing_an_Experiment_via_MQTT.html#9.1.3-Version-1)
# * [9.2.2 Remote Operation of a Laboratory Experiment](https://jckantor.github.io/cbe61622/09.02-Accessing_a_Remote_Experiment_via_MQTT.html#9.2.2-Remote-Operation-of-a-Laboratory-Experiment)
#
# ### machine
# * [5.1.3.1 Activity](https://jckantor.github.io/cbe61622/05.01-Getting_Started.html#5.1.3.1-Activity)
# * [5.3.1 Using the LCD 16x2 display](https://jckantor.github.io/cbe61622/05.03-LCD1602.html#5.3.1-Using-the-LCD-16x2-display)
# * [5.3.2 A simplified LCD16x2 class](https://jckantor.github.io/cbe61622/05.03-LCD1602.html#5.3.2-A-simplified-LCD16x2-class)
# * [5.3.3 A Simple Clock](https://jckantor.github.io/cbe61622/05.03-LCD1602.html#5.3.3-A-Simple-Clock)
# * [5.4 Managing Multiple Devices with an Event Loop](https://jckantor.github.io/cbe61622/05.04-Simple_Event_Loop.html#5.4-Managing-Multiple-Devices-with-an-Event-Loop)
# * [5.6.3 Single threaded, imperative coding](https://jckantor.github.io/cbe61622/05.06-Coding-Paradigms.html#5.6.3-Single-threaded,-imperative-coding)
#
# ### math
# * [2.1.2.1 Shot Noise](https://jckantor.github.io/cbe61622/02.01-Low-Level-Measurment.html#2.1.2.1-Shot-Noise)
# * [8.3 Machine Vision Applications](https://jckantor.github.io/cbe61622/08.03-Machine-Vision.html#8.3-Machine-Vision-Applications)
# * [8.3.1.3 Telecentric Lenses](https://jckantor.github.io/cbe61622/08.03-Machine-Vision.html#8.3.1.3-Telecentric-Lenses)
#
# ### matplotlib
# * [2.1.2.1 Shot Noise](https://jckantor.github.io/cbe61622/02.01-Low-Level-Measurment.html#2.1.2.1-Shot-Noise)
# * [2.2.1 Sampling signals](https://jckantor.github.io/cbe61622/02.02-Sampling-Continuous-Time-Signals.html#2.2.1-Sampling-signals)
# * [2.2.4 numpy.fft](https://jckantor.github.io/cbe61622/02.02-Sampling-Continuous-Time-Signals.html#2.2.4-numpy.fft)
# * [2.2.5 Examples of Fourier Transforms](https://jckantor.github.io/cbe61622/02.02-Sampling-Continuous-Time-Signals.html#2.2.5-Examples-of-Fourier-Transforms)
# * [2.2.9 Inverse Discrete Fourier Transform](https://jckantor.github.io/cbe61622/02.02-Sampling-Continuous-Time-Signals.html#2.2.9-Inverse-Discrete-Fourier-Transform)
# * [8.4.3 Matplotlib Demonstration](https://jckantor.github.io/cbe61622/08.04-rpi-test-libraries.html#8.4.3-Matplotlib-Demonstration)
# * [8.4.4 Scipy Demonstration](https://jckantor.github.io/cbe61622/08.04-rpi-test-libraries.html#8.4.4-Scipy-Demonstration)
# * [8.5.1.4 Capture to numpy array](https://jckantor.github.io/cbe61622/08.05-rpi-picamera_test.html#8.5.1.4-Capture-to-numpy-array)
# * [8.5.1.4 Capture to numpy array](https://jckantor.github.io/cbe61622/08.05-rpi-picamera_test.html#8.5.1.4-Capture-to-numpy-array)
# * [9.1.2.1 Proof of Concept](https://jckantor.github.io/cbe61622/09.01-Publishing_an_Experiment_via_MQTT.html#9.1.2.1-Proof-of-Concept)
# * [9.2.2 Remote Operation of a Laboratory Experiment](https://jckantor.github.io/cbe61622/09.02-Accessing_a_Remote_Experiment_via_MQTT.html#9.2.2-Remote-Operation-of-a-Laboratory-Experiment)
# * [9.2.3 Version 1](https://jckantor.github.io/cbe61622/09.02-Accessing_a_Remote_Experiment_via_MQTT.html#9.2.3-Version-1)
# * [10.11.1.1 Python Imports](https://jckantor.github.io/cbe61622/10.11-Computer-Vision-Experiments.html#10.11.1.1-Python-Imports)
# * [10.11.2 Particle Labeling Classes](https://jckantor.github.io/cbe61622/10.11-Computer-Vision-Experiments.html#10.11.2-Particle-Labeling-Classes)
# * [10.12.1.1 Labeler Class](https://jckantor.github.io/cbe61622/10.12-Computer-Vision-Development.html#10.12.1.1-Labeler-Class)
# * [10.12.1.2 Loading image files](https://jckantor.github.io/cbe61622/10.12-Computer-Vision-Development.html#10.12.1.2-Loading-image-files)
# * [10.12.1.3 Image Rescaling and Cropping](https://jckantor.github.io/cbe61622/10.12-Computer-Vision-Development.html#10.12.1.3-Image-Rescaling-and-Cropping)
# * [10.12.1.5 Integrating Channels into Labeler](https://jckantor.github.io/cbe61622/10.12-Computer-Vision-Development.html#10.12.1.5-Integrating-Channels-into-Labeler)
# * [10.12.3 Classes](https://jckantor.github.io/cbe61622/10.12-Computer-Vision-Development.html#10.12.3-Classes)
# * [10.13.1 Application](https://jckantor.github.io/cbe61622/10.13-Computer-Vision-Application.html#10.13.1-Application)
#
# ### numpy
# * [2.1.2.1 Shot Noise](https://jckantor.github.io/cbe61622/02.01-Low-Level-Measurment.html#2.1.2.1-Shot-Noise)
# * [2.2.1 Sampling signals](https://jckantor.github.io/cbe61622/02.02-Sampling-Continuous-Time-Signals.html#2.2.1-Sampling-signals)
# * [2.2.4 numpy.fft](https://jckantor.github.io/cbe61622/02.02-Sampling-Continuous-Time-Signals.html#2.2.4-numpy.fft)
# * [2.2.5 Examples of Fourier Transforms](https://jckantor.github.io/cbe61622/02.02-Sampling-Continuous-Time-Signals.html#2.2.5-Examples-of-Fourier-Transforms)
# * [2.2.9 Inverse Discrete Fourier Transform](https://jckantor.github.io/cbe61622/02.02-Sampling-Continuous-Time-Signals.html#2.2.9-Inverse-Discrete-Fourier-Transform)
# * [8.3.1.3 Telecentric Lenses](https://jckantor.github.io/cbe61622/08.03-Machine-Vision.html#8.3.1.3-Telecentric-Lenses)
# * [8.4.1 Show numpy configuration](https://jckantor.github.io/cbe61622/08.04-rpi-test-libraries.html#8.4.1-Show-numpy-configuration)
# * [8.4.2 Matrix Multiplication Benchmark](https://jckantor.github.io/cbe61622/08.04-rpi-test-libraries.html#8.4.2-Matrix-Multiplication-Benchmark)
# * [8.4.4 Scipy Demonstration](https://jckantor.github.io/cbe61622/08.04-rpi-test-libraries.html#8.4.4-Scipy-Demonstration)
# * [8.5.1.4 Capture to numpy array](https://jckantor.github.io/cbe61622/08.05-rpi-picamera_test.html#8.5.1.4-Capture-to-numpy-array)
# * [8.5.1.4 Capture to numpy array](https://jckantor.github.io/cbe61622/08.05-rpi-picamera_test.html#8.5.1.4-Capture-to-numpy-array)
# * [9.1.2.1 Proof of Concept](https://jckantor.github.io/cbe61622/09.01-Publishing_an_Experiment_via_MQTT.html#9.1.2.1-Proof-of-Concept)
# * [9.2.2 Remote Operation of a Laboratory Experiment](https://jckantor.github.io/cbe61622/09.02-Accessing_a_Remote_Experiment_via_MQTT.html#9.2.2-Remote-Operation-of-a-Laboratory-Experiment)
# * [9.2.3 Version 1](https://jckantor.github.io/cbe61622/09.02-Accessing_a_Remote_Experiment_via_MQTT.html#9.2.3-Version-1)
# * [10.11.1.1 Python Imports](https://jckantor.github.io/cbe61622/10.11-Computer-Vision-Experiments.html#10.11.1.1-Python-Imports)
# * [10.11.2 Particle Labeling Classes](https://jckantor.github.io/cbe61622/10.11-Computer-Vision-Experiments.html#10.11.2-Particle-Labeling-Classes)
# * [10.12.1.1 Labeler Class](https://jckantor.github.io/cbe61622/10.12-Computer-Vision-Development.html#10.12.1.1-Labeler-Class)
# * [10.12.1.2 Loading image files](https://jckantor.github.io/cbe61622/10.12-Computer-Vision-Development.html#10.12.1.2-Loading-image-files)
# * [10.12.1.3 Image Rescaling and Cropping](https://jckantor.github.io/cbe61622/10.12-Computer-Vision-Development.html#10.12.1.3-Image-Rescaling-and-Cropping)
# * [10.12.1.5 Integrating Channels into Labeler](https://jckantor.github.io/cbe61622/10.12-Computer-Vision-Development.html#10.12.1.5-Integrating-Channels-into-Labeler)
# * [10.12.3 Classes](https://jckantor.github.io/cbe61622/10.12-Computer-Vision-Development.html#10.12.3-Classes)
# * [10.13.1 Application](https://jckantor.github.io/cbe61622/10.13-Computer-Vision-Application.html#10.13.1-Application)
#
# ### os
# * [A.2.2 Method 2. Cloning a git repository](https://jckantor.github.io/cbe61622/A.02-Downloading_Python_source_files_from_github.html#A.2.2-Method-2.-Cloning-a-git-repository)
# * [A.2.2 Method 2. Cloning a git repository](https://jckantor.github.io/cbe61622/A.02-Downloading_Python_source_files_from_github.html#A.2.2-Method-2.-Cloning-a-git-repository)
# * [A.2.2.1 Commit and push changes](https://jckantor.github.io/cbe61622/A.02-Downloading_Python_source_files_from_github.html#A.2.2.1-Commit-and-push-changes)
# * [B.1.3.2 Toggle on-board led](https://jckantor.github.io/cbe61622/B.01-Particle_CLI.html#B.1.3.2-Toggle-on-board-led)
# * [B.1.3.3 Reading Grove Light Sensor V1.2](https://jckantor.github.io/cbe61622/B.01-Particle_CLI.html#B.1.3.3-Reading-Grove-Light-Sensor-V1.2)
#
# ### paho
# * [9.1.2.1 Proof of Concept](https://jckantor.github.io/cbe61622/09.01-Publishing_an_Experiment_via_MQTT.html#9.1.2.1-Proof-of-Concept)
# * [9.1.2.1 Proof of Concept](https://jckantor.github.io/cbe61622/09.01-Publishing_an_Experiment_via_MQTT.html#9.1.2.1-Proof-of-Concept)
# * [9.1.3 Version 1](https://jckantor.github.io/cbe61622/09.01-Publishing_an_Experiment_via_MQTT.html#9.1.3-Version-1)
# * [9.1.3 Version 1](https://jckantor.github.io/cbe61622/09.01-Publishing_an_Experiment_via_MQTT.html#9.1.3-Version-1)
# * [9.2.2 Remote Operation of a Laboratory Experiment](https://jckantor.github.io/cbe61622/09.02-Accessing_a_Remote_Experiment_via_MQTT.html#9.2.2-Remote-Operation-of-a-Laboratory-Experiment)
# * [9.2.2 Remote Operation of a Laboratory Experiment](https://jckantor.github.io/cbe61622/09.02-Accessing_a_Remote_Experiment_via_MQTT.html#9.2.2-Remote-Operation-of-a-Laboratory-Experiment)
# * [9.2.3 Version 1](https://jckantor.github.io/cbe61622/09.02-Accessing_a_Remote_Experiment_via_MQTT.html#9.2.3-Version-1)
# * [9.2.3 Version 1](https://jckantor.github.io/cbe61622/09.02-Accessing_a_Remote_Experiment_via_MQTT.html#9.2.3-Version-1)
# * [9.3.3 Receiving data from Particle Argon device](https://jckantor.github.io/cbe61622/09.03-Miscellaneous_Notes.html#9.3.3-Receiving-data-from-Particle-Argon-device)
# * [9.3.3 Receiving data from Particle Argon device](https://jckantor.github.io/cbe61622/09.03-Miscellaneous_Notes.html#9.3.3-Receiving-data-from-Particle-Argon-device)
#
# ### picamera
# * [8.5.1 PiCamera](https://jckantor.github.io/cbe61622/08.05-rpi-picamera_test.html#8.5.1-PiCamera)
# * [8.5.1.1 Camera preview](https://jckantor.github.io/cbe61622/08.05-rpi-picamera_test.html#8.5.1.1-Camera-preview)
# * [8.5.1.1 Camera preview](https://jckantor.github.io/cbe61622/08.05-rpi-picamera_test.html#8.5.1.1-Camera-preview)
# * [8.5.1.2 Capture to stream and display](https://jckantor.github.io/cbe61622/08.05-rpi-picamera_test.html#8.5.1.2-Capture-to-stream-and-display)
# * [8.5.1.3 Camera Settings](https://jckantor.github.io/cbe61622/08.05-rpi-picamera_test.html#8.5.1.3-Camera-Settings)
# * [8.5.1.3 Camera Settings](https://jckantor.github.io/cbe61622/08.05-rpi-picamera_test.html#8.5.1.3-Camera-Settings)
# * [8.5.1.4 Capture to numpy array](https://jckantor.github.io/cbe61622/08.05-rpi-picamera_test.html#8.5.1.4-Capture-to-numpy-array)
# * [8.5.1.4 Capture to numpy array](https://jckantor.github.io/cbe61622/08.05-rpi-picamera_test.html#8.5.1.4-Capture-to-numpy-array)
#
# ### PIL
# * [8.5.1.2 Capture to stream and display](https://jckantor.github.io/cbe61622/08.05-rpi-picamera_test.html#8.5.1.2-Capture-to-stream-and-display)
# * [8.5.1.3 Camera Settings](https://jckantor.github.io/cbe61622/08.05-rpi-picamera_test.html#8.5.1.3-Camera-Settings)
#
# ### random
# * [2.1.2.1 Shot Noise](https://jckantor.github.io/cbe61622/02.01-Low-Level-Measurment.html#2.1.2.1-Shot-Noise)
#
# ### re
# * [7.1.1.2 Utility functions](https://jckantor.github.io/cbe61622/07.01-Communicating _via_TCP.html#7.1.1.2-Utility-functions)
# * [7.2.1.2 Utility functions](https://jckantor.github.io/cbe61622/07.02-Stepper_Motor_Control_via_I2C.html#7.2.1.2-Utility-functions)
# * [B.1.3.3 Reading Grove Light Sensor V1.2](https://jckantor.github.io/cbe61622/B.01-Particle_CLI.html#B.1.3.3-Reading-Grove-Light-Sensor-V1.2)
# * [B.3.1.2 Utility functions](https://jckantor.github.io/cbe61622/B.03-Particle-CLI.html#B.3.1.2-Utility-functions)
# * [B.4.1.2 Utility functions](https://jckantor.github.io/cbe61622/B.04-Ultrasonic_Distance_Ranger.html#B.4.1.2-Utility-functions)
# * [B.5.1.2 Utility functions](https://jckantor.github.io/cbe61622/B.05-Simple_Stop_Watch_using_Interrupts.html#B.5.1.2-Utility-functions)
#
# ### rp2
# * [5.8.4 Programmable Input/Ouput (PIO)](https://jckantor.github.io/cbe61622/05.08-Stepper-Motors.html#5.8.4-Programmable-Input/Ouput-(PIO))
# * [5.9.3 Interacting PIO programs](https://jckantor.github.io/cbe61622/05.09-PIO-Programming.html#5.9.3-Interacting-PIO-programs)
#
# ### simpy
# * [9.1.3 Version 1](https://jckantor.github.io/cbe61622/09.01-Publishing_an_Experiment_via_MQTT.html#9.1.3-Version-1)
# * [A.4.1 Blinkers](https://jckantor.github.io/cbe61622/A.04-Scheduling-Real-Time-Events-with-Simpy.html#A.4.1-Blinkers)
#
# ### subprocess
# * [7.1.1.2 Utility functions](https://jckantor.github.io/cbe61622/07.01-Communicating _via_TCP.html#7.1.1.2-Utility-functions)
# * [7.2.1.2 Utility functions](https://jckantor.github.io/cbe61622/07.02-Stepper_Motor_Control_via_I2C.html#7.2.1.2-Utility-functions)
# * [A.2.1 Method 1. Downloading individual Python files with wget](https://jckantor.github.io/cbe61622/A.02-Downloading_Python_source_files_from_github.html#A.2.1-Method-1.-Downloading-individual-Python-files-with-wget)
# * [B.1.2 Login to Particle](https://jckantor.github.io/cbe61622/B.01-Particle_CLI.html#B.1.2-Login-to-Particle)
# * [B.1.3.2 Toggle on-board led](https://jckantor.github.io/cbe61622/B.01-Particle_CLI.html#B.1.3.2-Toggle-on-board-led)
# * [B.1.3.3 Reading Grove Light Sensor V1.2](https://jckantor.github.io/cbe61622/B.01-Particle_CLI.html#B.1.3.3-Reading-Grove-Light-Sensor-V1.2)
# * [B.2.2 Login to Particle](https://jckantor.github.io/cbe61622/B.02-Particle_Coding.html#B.2.2-Login-to-Particle)
# * [B.3.1.2 Utility functions](https://jckantor.github.io/cbe61622/B.03-Particle-CLI.html#B.3.1.2-Utility-functions)
# * [B.4.1.2 Utility functions](https://jckantor.github.io/cbe61622/B.04-Ultrasonic_Distance_Ranger.html#B.4.1.2-Utility-functions)
# * [B.5.1.2 Utility functions](https://jckantor.github.io/cbe61622/B.05-Simple_Stop_Watch_using_Interrupts.html#B.5.1.2-Utility-functions)
#
# ### sys
# * [5.8.4 Programmable Input/Ouput (PIO)](https://jckantor.github.io/cbe61622/05.08-Stepper-Motors.html#5.8.4-Programmable-Input/Ouput-(PIO))
# * [5.8.4 Programmable Input/Ouput (PIO)](https://jckantor.github.io/cbe61622/05.08-Stepper-Motors.html#5.8.4-Programmable-Input/Ouput-(PIO))
# * [5.8.4 Programmable Input/Ouput (PIO)](https://jckantor.github.io/cbe61622/05.08-Stepper-Motors.html#5.8.4-Programmable-Input/Ouput-(PIO))
# * [A.2.2 Method 2. Cloning a git repository](https://jckantor.github.io/cbe61622/A.02-Downloading_Python_source_files_from_github.html#A.2.2-Method-2.-Cloning-a-git-repository)
# * [A.2.2 Method 2. Cloning a git repository](https://jckantor.github.io/cbe61622/A.02-Downloading_Python_source_files_from_github.html#A.2.2-Method-2.-Cloning-a-git-repository)
# * [A.2.2 Method 2. Cloning a git repository](https://jckantor.github.io/cbe61622/A.02-Downloading_Python_source_files_from_github.html#A.2.2-Method-2.-Cloning-a-git-repository)
#
# ### time
# * [5.1.3.1 Activity](https://jckantor.github.io/cbe61622/05.01-Getting_Started.html#5.1.3.1-Activity)
# * [5.3.3 A Simple Clock](https://jckantor.github.io/cbe61622/05.03-LCD1602.html#5.3.3-A-Simple-Clock)
# * [5.4 Managing Multiple Devices with an Event Loop](https://jckantor.github.io/cbe61622/05.04-Simple_Event_Loop.html#5.4-Managing-Multiple-Devices-with-an-Event-Loop)
# * [5.5.3 Single threaded, imperative coding](https://jckantor.github.io/cbe61622/05.05-Coding-Paradigms.html#5.5.3-Single-threaded,-imperative-coding)
# * [5.5.3 Single threaded, imperative coding](https://jckantor.github.io/cbe61622/05.05-Coding-Paradigms.html#5.5.3-Single-threaded,-imperative-coding)
# * [5.6.3 Single threaded, imperative coding](https://jckantor.github.io/cbe61622/05.06-Coding-Paradigms.html#5.6.3-Single-threaded,-imperative-coding)
# * [5.6.3 Single threaded, imperative coding](https://jckantor.github.io/cbe61622/05.06-Coding-Paradigms.html#5.6.3-Single-threaded,-imperative-coding)
# * [5.6.3 Single threaded, imperative coding](https://jckantor.github.io/cbe61622/05.06-Coding-Paradigms.html#5.6.3-Single-threaded,-imperative-coding)
# * [5.7.2.1 Polling](https://jckantor.github.io/cbe61622/05.07-Event-Driven-Programming.html#5.7.2.1-Polling)
# * [5.7.2.2 Timer](https://jckantor.github.io/cbe61622/05.07-Event-Driven-Programming.html#5.7.2.2-Timer)
# * [5.7.2.2 Timer](https://jckantor.github.io/cbe61622/05.07-Event-Driven-Programming.html#5.7.2.2-Timer)
# * [5.7.3 Interrupt Requests and Service Routines: IRQ/ISR](https://jckantor.github.io/cbe61622/05.07-Event-Driven-Programming.html#5.7.3-Interrupt-Requests-and-Service-Routines:-IRQ/ISR)
# * [5.7.3 Interrupt Requests and Service Routines: IRQ/ISR](https://jckantor.github.io/cbe61622/05.07-Event-Driven-Programming.html#5.7.3-Interrupt-Requests-and-Service-Routines:-IRQ/ISR)
# * [5.7.3.1 Capturing data via IRQ/ISR's](https://jckantor.github.io/cbe61622/05.07-Event-Driven-Programming.html#5.7.3.1-Capturing-data-via-IRQ/ISR's)
# * [5.8.3 Driving the 28BYJ-48 Stepper Motor](https://jckantor.github.io/cbe61622/05.08-Stepper-Motors.html#5.8.3-Driving-the-28BYJ-48-Stepper-Motor)
# * [5.8.4 Programmable Input/Ouput (PIO)](https://jckantor.github.io/cbe61622/05.08-Stepper-Motors.html#5.8.4-Programmable-Input/Ouput-(PIO))
# * [5.9.1 Setting multiple pins from Python](https://jckantor.github.io/cbe61622/05.09-PIO-Programming.html#5.9.1-Setting-multiple-pins-from-Python)
# * [5.9.2 Writing Stepper Steps to pins](https://jckantor.github.io/cbe61622/05.09-PIO-Programming.html#5.9.2-Writing-Stepper-Steps-to-pins)
# * [5.9.2 Writing Stepper Steps to pins](https://jckantor.github.io/cbe61622/05.09-PIO-Programming.html#5.9.2-Writing-Stepper-Steps-to-pins)
# * [5.9.2 Writing Stepper Steps to pins](https://jckantor.github.io/cbe61622/05.09-PIO-Programming.html#5.9.2-Writing-Stepper-Steps-to-pins)
# * [5.9.3 Interacting PIO programs](https://jckantor.github.io/cbe61622/05.09-PIO-Programming.html#5.9.3-Interacting-PIO-programs)
# * [5.9.3 Interacting PIO programs](https://jckantor.github.io/cbe61622/05.09-PIO-Programming.html#5.9.3-Interacting-PIO-programs)
# * [5.10.1 ESP01 class](https://jckantor.github.io/cbe61622/05.10-Wifi-with-ESP-01.html#5.10.1-ESP01-class)
# * [8.5.1.1 Camera preview](https://jckantor.github.io/cbe61622/08.05-rpi-picamera_test.html#8.5.1.1-Camera-preview)
# * [8.5.1.1 Camera preview](https://jckantor.github.io/cbe61622/08.05-rpi-picamera_test.html#8.5.1.1-Camera-preview)
# * [8.5.1.2 Capture to stream and display](https://jckantor.github.io/cbe61622/08.05-rpi-picamera_test.html#8.5.1.2-Capture-to-stream-and-display)
# * [8.5.1.3 Camera Settings](https://jckantor.github.io/cbe61622/08.05-rpi-picamera_test.html#8.5.1.3-Camera-Settings)
# * [8.5.1.3 Camera Settings](https://jckantor.github.io/cbe61622/08.05-rpi-picamera_test.html#8.5.1.3-Camera-Settings)
# * [8.5.1.4 Capture to numpy array](https://jckantor.github.io/cbe61622/08.05-rpi-picamera_test.html#8.5.1.4-Capture-to-numpy-array)
# * [8.5.1.4 Capture to numpy array](https://jckantor.github.io/cbe61622/08.05-rpi-picamera_test.html#8.5.1.4-Capture-to-numpy-array)
# * [9.1.2.1 Proof of Concept](https://jckantor.github.io/cbe61622/09.01-Publishing_an_Experiment_via_MQTT.html#9.1.2.1-Proof-of-Concept)
# * [9.1.3 Version 1](https://jckantor.github.io/cbe61622/09.01-Publishing_an_Experiment_via_MQTT.html#9.1.3-Version-1)
# * [9.2.2 Remote Operation of a Laboratory Experiment](https://jckantor.github.io/cbe61622/09.02-Accessing_a_Remote_Experiment_via_MQTT.html#9.2.2-Remote-Operation-of-a-Laboratory-Experiment)
# * [9.2.3 Version 1](https://jckantor.github.io/cbe61622/09.02-Accessing_a_Remote_Experiment_via_MQTT.html#9.2.3-Version-1)
# * [9.3.3 Receiving data from Particle Argon device](https://jckantor.github.io/cbe61622/09.03-Miscellaneous_Notes.html#9.3.3-Receiving-data-from-Particle-Argon-device)
# * [A.3.3 Blinker](https://jckantor.github.io/cbe61622/A.03-Getting-Started-with-Pymata4.html#A.3.3-Blinker)
# * [A.3.4 Handling a Keyboard Interrupt](https://jckantor.github.io/cbe61622/A.03-Getting-Started-with-Pymata4.html#A.3.4-Handling-a-Keyboard-Interrupt)
# * [A.3.5 Getting Information about the Arduino](https://jckantor.github.io/cbe61622/A.03-Getting-Started-with-Pymata4.html#A.3.5-Getting-Information-about-the-Arduino)
# * [A.3.6 Temperature Control Lab Shield](https://jckantor.github.io/cbe61622/A.03-Getting-Started-with-Pymata4.html#A.3.6-Temperature-Control-Lab-Shield)
# * [A.4.1 Blinkers](https://jckantor.github.io/cbe61622/A.04-Scheduling-Real-Time-Events-with-Simpy.html#A.4.1-Blinkers)
# * [A.4.2 Asyncio](https://jckantor.github.io/cbe61622/A.04-Scheduling-Real-Time-Events-with-Simpy.html#A.4.2-Asyncio)
# * [B.1.3.2 Toggle on-board led](https://jckantor.github.io/cbe61622/B.01-Particle_CLI.html#B.1.3.2-Toggle-on-board-led)
# * [B.1.3.3 Reading Grove Light Sensor V1.2](https://jckantor.github.io/cbe61622/B.01-Particle_CLI.html#B.1.3.3-Reading-Grove-Light-Sensor-V1.2)
#
# ### urllib
# * [A.2.2.1 Commit and push changes](https://jckantor.github.io/cbe61622/A.02-Downloading_Python_source_files_from_github.html#A.2.2.1-Commit-and-push-changes)
#
# ### uuid
# * [9.2.2 Remote Operation of a Laboratory Experiment](https://jckantor.github.io/cbe61622/09.02-Accessing_a_Remote_Experiment_via_MQTT.html#9.2.2-Remote-Operation-of-a-Laboratory-Experiment)
