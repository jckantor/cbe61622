# %% [markdown]
# # [cbe61622](https://jckantor.github.io/cbe61622)
#
# ## Index of Python Libraries used in this Repository
#
# ### asyncio
# * [A.4.2 Asyncio](https://jckantor.github.io/cbe61622/A.04-Scheduling-Real-Time-Events-with-Simpy.html#A.4.2-Asyncio)
#
# ### cv2
# * [4.5.1.4 Capture to numpy array](https://jckantor.github.io/cbe61622/04.05-rpi-picamera_test.html#4.5.1.4-Capture-to-numpy-array)
# * [10.11.1.1 Python Imports](https://jckantor.github.io/cbe61622/10.11-Computer-Vision-Experiments.html#10.11.1.1-Python-Imports)
# * [10.11.2 Particle Labeling Classes](https://jckantor.github.io/cbe61622/10.11-Computer-Vision-Experiments.html#10.11.2-Particle-Labeling-Classes)
# * [10.12.1.1 Labeler Class](https://jckantor.github.io/cbe61622/10.12-Computer-Vision-Development.html#10.12.1.1-Labeler-Class)
# * [10.12.1.2 Loading image files](https://jckantor.github.io/cbe61622/10.12-Computer-Vision-Development.html#10.12.1.2-Loading-image-files)
# * [10.12.1.3 Image Rescaling and Cropping](https://jckantor.github.io/cbe61622/10.12-Computer-Vision-Development.html#10.12.1.3-Image-Rescaling-and-Cropping)
# * [10.12.1.5 Integrating Channels into Labeler](https://jckantor.github.io/cbe61622/10.12-Computer-Vision-Development.html#10.12.1.5-Integrating-Channels-into-Labeler)
# * [10.12.3 Classes](https://jckantor.github.io/cbe61622/10.12-Computer-Vision-Development.html#10.12.3-Classes)
# * [10.13.1 Application](https://jckantor.github.io/cbe61622/10.13-Computer-Vision-Application.html#10.13.1-Application)
#
# ### getpass
# * [2.1.2 Login to Particle](https://jckantor.github.io/cbe61622/02.01-Particle_CLI.html#2.1.2-Login-to-Particle)
# * [2.2.2 Login to Particle](https://jckantor.github.io/cbe61622/02.02-Particle_Coding.html#2.2.2-Login-to-Particle)
# * [2.3.1.3 Login to Particle](https://jckantor.github.io/cbe61622/02.03-Particle-CLI.html#2.3.1.3-Login-to-Particle)
# * [2.4.1.3 Login to Particle](https://jckantor.github.io/cbe61622/02.04-Ultrasonic_Distance_Ranger.html#2.4.1.3-Login-to-Particle)
# * [2.5.1.3 Login to Particle](https://jckantor.github.io/cbe61622/02.05-Simple_Stop_Watch_using_Interrupts.html#2.5.1.3-Login-to-Particle)
# * [9.1.1.4 Select a device](https://jckantor.github.io/cbe61622/09.01-Communicating _via_TCP.html#9.1.1.4-Select-a-device)
# * [9.2.1.3 Login to Particle](https://jckantor.github.io/cbe61622/09.02-Stepper_Motor_Control_via_I2C.html#9.2.1.3-Login-to-Particle)
#
# ### glob
# * [10.12.1.1 Labeler Class](https://jckantor.github.io/cbe61622/10.12-Computer-Vision-Development.html#10.12.1.1-Labeler-Class)
# * [10.12.1.1 Labeler Class](https://jckantor.github.io/cbe61622/10.12-Computer-Vision-Development.html#10.12.1.1-Labeler-Class)
# * [10.12.1.2 Loading image files](https://jckantor.github.io/cbe61622/10.12-Computer-Vision-Development.html#10.12.1.2-Loading-image-files)
# * [10.12.1.3 Image Rescaling and Cropping](https://jckantor.github.io/cbe61622/10.12-Computer-Vision-Development.html#10.12.1.3-Image-Rescaling-and-Cropping)
# * [10.12.1.5 Integrating Channels into Labeler](https://jckantor.github.io/cbe61622/10.12-Computer-Vision-Development.html#10.12.1.5-Integrating-Channels-into-Labeler)
# * [10.13.2 Demonstrations](https://jckantor.github.io/cbe61622/10.13-Computer-Vision-Application.html#10.13.2-Demonstrations)
#
# ### hello_world
# * [A.2.1 Method 1. Downloading individual Python files with wget](https://jckantor.github.io/cbe61622/A.02-Downloading_Python_source_files_from_github.html#A.2.1-Method-1.-Downloading-individual-Python-files-with-wget)
# * [A.2.2 Method 2. Cloning a git repository](https://jckantor.github.io/cbe61622/A.02-Downloading_Python_source_files_from_github.html#A.2.2-Method-2.-Cloning-a-git-repository)
#
# ### importlib
# * [A.2.1 Method 1. Downloading individual Python files with wget](https://jckantor.github.io/cbe61622/A.02-Downloading_Python_source_files_from_github.html#A.2.1-Method-1.-Downloading-individual-Python-files-with-wget)
# * [A.2.2 Method 2. Cloning a git repository](https://jckantor.github.io/cbe61622/A.02-Downloading_Python_source_files_from_github.html#A.2.2-Method-2.-Cloning-a-git-repository)
#
# ### json
# * [6.1.3 Version 1](https://jckantor.github.io/cbe61622/06.01-Publishing_an_Experiment_via_MQTT.html#6.1.3-Version-1)
# * [6.2.2 Remote Operation of a Laboratory Experiment](https://jckantor.github.io/cbe61622/06.02-Accessing_a_Remote_Experiment_via_MQTT.html#6.2.2-Remote-Operation-of-a-Laboratory-Experiment)
#
# ### machine
# * [3.1.3.1 Activity](https://jckantor.github.io/cbe61622/03.01-Getting_Started.html#3.1.3.1-Activity)
# * [3.3.1 Using the LCD 16x2 display](https://jckantor.github.io/cbe61622/03.03-LCD1602.html#3.3.1-Using-the-LCD-16x2-display)
# * [3.3.2 A simplified LCD16x2 class](https://jckantor.github.io/cbe61622/03.03-LCD1602.html#3.3.2-A-simplified-LCD16x2-class)
# * [3.3.3 A Simple Clock](https://jckantor.github.io/cbe61622/03.03-LCD1602.html#3.3.3-A-Simple-Clock)
# * [3.4 Managing Multiple Devices with an Event Loop](https://jckantor.github.io/cbe61622/03.04-Simple_Event_Loop.html#3.4-Managing-Multiple-Devices-with-an-Event-Loop)
# * [3.6.3 Single threaded, imperative coding](https://jckantor.github.io/cbe61622/03.06-Coding-Paradigms.html#3.6.3-Single-threaded,-imperative-coding)
#
# ### math
# * [3.11.2.1 Shot Noise](https://jckantor.github.io/cbe61622/03.11-Low-Level-Measurment.html#3.11.2.1-Shot-Noise)
# * [4.3 Machine Vision Applications](https://jckantor.github.io/cbe61622/04.03-Machine-Vision.html#4.3-Machine-Vision-Applications)
# * [4.3.1.3 Telecentric Lenses](https://jckantor.github.io/cbe61622/04.03-Machine-Vision.html#4.3.1.3-Telecentric-Lenses)
#
# ### matplotlib
# * [3.11.2.1 Shot Noise](https://jckantor.github.io/cbe61622/03.11-Low-Level-Measurment.html#3.11.2.1-Shot-Noise)
# * [3.12.1 Sampling signals](https://jckantor.github.io/cbe61622/03.12-Sampling-Continuous-Time-Signals.html#3.12.1-Sampling-signals)
# * [3.12.4 numpy.fft](https://jckantor.github.io/cbe61622/03.12-Sampling-Continuous-Time-Signals.html#3.12.4-numpy.fft)
# * [3.12.5 Examples of Fourier Transforms](https://jckantor.github.io/cbe61622/03.12-Sampling-Continuous-Time-Signals.html#3.12.5-Examples-of-Fourier-Transforms)
# * [3.12.9 Inverse Discrete Fourier Transform](https://jckantor.github.io/cbe61622/03.12-Sampling-Continuous-Time-Signals.html#3.12.9-Inverse-Discrete-Fourier-Transform)
# * [4.4.3 Matplotlib Demonstration](https://jckantor.github.io/cbe61622/04.04-rpi-test-libraries.html#4.4.3-Matplotlib-Demonstration)
# * [4.4.4 Scipy Demonstration](https://jckantor.github.io/cbe61622/04.04-rpi-test-libraries.html#4.4.4-Scipy-Demonstration)
# * [4.5.1.4 Capture to numpy array](https://jckantor.github.io/cbe61622/04.05-rpi-picamera_test.html#4.5.1.4-Capture-to-numpy-array)
# * [4.5.1.4 Capture to numpy array](https://jckantor.github.io/cbe61622/04.05-rpi-picamera_test.html#4.5.1.4-Capture-to-numpy-array)
# * [6.1.2.1 Proof of Concept](https://jckantor.github.io/cbe61622/06.01-Publishing_an_Experiment_via_MQTT.html#6.1.2.1-Proof-of-Concept)
# * [6.2.2 Remote Operation of a Laboratory Experiment](https://jckantor.github.io/cbe61622/06.02-Accessing_a_Remote_Experiment_via_MQTT.html#6.2.2-Remote-Operation-of-a-Laboratory-Experiment)
# * [6.2.3 Version 1](https://jckantor.github.io/cbe61622/06.02-Accessing_a_Remote_Experiment_via_MQTT.html#6.2.3-Version-1)
# * [10.11.1.1 Python Imports](https://jckantor.github.io/cbe61622/10.11-Computer-Vision-Experiments.html#10.11.1.1-Python-Imports)
# * [10.11.2 Particle Labeling Classes](https://jckantor.github.io/cbe61622/10.11-Computer-Vision-Experiments.html#10.11.2-Particle-Labeling-Classes)
# * [10.12.1.1 Labeler Class](https://jckantor.github.io/cbe61622/10.12-Computer-Vision-Development.html#10.12.1.1-Labeler-Class)
# * [10.12.1.2 Loading image files](https://jckantor.github.io/cbe61622/10.12-Computer-Vision-Development.html#10.12.1.2-Loading-image-files)
# * [10.12.1.3 Image Rescaling and Cropping](https://jckantor.github.io/cbe61622/10.12-Computer-Vision-Development.html#10.12.1.3-Image-Rescaling-and-Cropping)
# * [10.12.1.5 Integrating Channels into Labeler](https://jckantor.github.io/cbe61622/10.12-Computer-Vision-Development.html#10.12.1.5-Integrating-Channels-into-Labeler)
# * [10.12.3 Classes](https://jckantor.github.io/cbe61622/10.12-Computer-Vision-Development.html#10.12.3-Classes)
# * [10.13.1 Application](https://jckantor.github.io/cbe61622/10.13-Computer-Vision-Application.html#10.13.1-Application)
#
# ### numpy
# * [3.11.2.1 Shot Noise](https://jckantor.github.io/cbe61622/03.11-Low-Level-Measurment.html#3.11.2.1-Shot-Noise)
# * [3.12.1 Sampling signals](https://jckantor.github.io/cbe61622/03.12-Sampling-Continuous-Time-Signals.html#3.12.1-Sampling-signals)
# * [3.12.4 numpy.fft](https://jckantor.github.io/cbe61622/03.12-Sampling-Continuous-Time-Signals.html#3.12.4-numpy.fft)
# * [3.12.5 Examples of Fourier Transforms](https://jckantor.github.io/cbe61622/03.12-Sampling-Continuous-Time-Signals.html#3.12.5-Examples-of-Fourier-Transforms)
# * [3.12.9 Inverse Discrete Fourier Transform](https://jckantor.github.io/cbe61622/03.12-Sampling-Continuous-Time-Signals.html#3.12.9-Inverse-Discrete-Fourier-Transform)
# * [4.3.1.3 Telecentric Lenses](https://jckantor.github.io/cbe61622/04.03-Machine-Vision.html#4.3.1.3-Telecentric-Lenses)
# * [4.4.1 Show numpy configuration](https://jckantor.github.io/cbe61622/04.04-rpi-test-libraries.html#4.4.1-Show-numpy-configuration)
# * [4.4.2 Matrix Multiplication Benchmark](https://jckantor.github.io/cbe61622/04.04-rpi-test-libraries.html#4.4.2-Matrix-Multiplication-Benchmark)
# * [4.4.4 Scipy Demonstration](https://jckantor.github.io/cbe61622/04.04-rpi-test-libraries.html#4.4.4-Scipy-Demonstration)
# * [4.5.1.4 Capture to numpy array](https://jckantor.github.io/cbe61622/04.05-rpi-picamera_test.html#4.5.1.4-Capture-to-numpy-array)
# * [4.5.1.4 Capture to numpy array](https://jckantor.github.io/cbe61622/04.05-rpi-picamera_test.html#4.5.1.4-Capture-to-numpy-array)
# * [6.1.2.1 Proof of Concept](https://jckantor.github.io/cbe61622/06.01-Publishing_an_Experiment_via_MQTT.html#6.1.2.1-Proof-of-Concept)
# * [6.2.2 Remote Operation of a Laboratory Experiment](https://jckantor.github.io/cbe61622/06.02-Accessing_a_Remote_Experiment_via_MQTT.html#6.2.2-Remote-Operation-of-a-Laboratory-Experiment)
# * [6.2.3 Version 1](https://jckantor.github.io/cbe61622/06.02-Accessing_a_Remote_Experiment_via_MQTT.html#6.2.3-Version-1)
# * [10.11.1.1 Python Imports](https://jckantor.github.io/cbe61622/10.11-Computer-Vision-Experiments.html#10.11.1.1-Python-Imports)
# * [10.11.2 Particle Labeling Classes](https://jckantor.github.io/cbe61622/10.11-Computer-Vision-Experiments.html#10.11.2-Particle-Labeling-Classes)
# * [10.12.1.1 Labeler Class](https://jckantor.github.io/cbe61622/10.12-Computer-Vision-Development.html#10.12.1.1-Labeler-Class)
# * [10.12.1.2 Loading image files](https://jckantor.github.io/cbe61622/10.12-Computer-Vision-Development.html#10.12.1.2-Loading-image-files)
# * [10.12.1.3 Image Rescaling and Cropping](https://jckantor.github.io/cbe61622/10.12-Computer-Vision-Development.html#10.12.1.3-Image-Rescaling-and-Cropping)
# * [10.12.1.5 Integrating Channels into Labeler](https://jckantor.github.io/cbe61622/10.12-Computer-Vision-Development.html#10.12.1.5-Integrating-Channels-into-Labeler)
# * [10.12.3 Classes](https://jckantor.github.io/cbe61622/10.12-Computer-Vision-Development.html#10.12.3-Classes)
# * [10.13.1 Application](https://jckantor.github.io/cbe61622/10.13-Computer-Vision-Application.html#10.13.1-Application)
#
# ### os
# * [2.1.3.2 Toggle on-board led](https://jckantor.github.io/cbe61622/02.01-Particle_CLI.html#2.1.3.2-Toggle-on-board-led)
# * [2.1.3.3 Reading Grove Light Sensor V1.2](https://jckantor.github.io/cbe61622/02.01-Particle_CLI.html#2.1.3.3-Reading-Grove-Light-Sensor-V1.2)
# * [A.2.2 Method 2. Cloning a git repository](https://jckantor.github.io/cbe61622/A.02-Downloading_Python_source_files_from_github.html#A.2.2-Method-2.-Cloning-a-git-repository)
# * [A.2.2 Method 2. Cloning a git repository](https://jckantor.github.io/cbe61622/A.02-Downloading_Python_source_files_from_github.html#A.2.2-Method-2.-Cloning-a-git-repository)
# * [A.2.2.1 Commit and push changes](https://jckantor.github.io/cbe61622/A.02-Downloading_Python_source_files_from_github.html#A.2.2.1-Commit-and-push-changes)
#
# ### paho
# * [6.1.2.1 Proof of Concept](https://jckantor.github.io/cbe61622/06.01-Publishing_an_Experiment_via_MQTT.html#6.1.2.1-Proof-of-Concept)
# * [6.1.2.1 Proof of Concept](https://jckantor.github.io/cbe61622/06.01-Publishing_an_Experiment_via_MQTT.html#6.1.2.1-Proof-of-Concept)
# * [6.1.3 Version 1](https://jckantor.github.io/cbe61622/06.01-Publishing_an_Experiment_via_MQTT.html#6.1.3-Version-1)
# * [6.1.3 Version 1](https://jckantor.github.io/cbe61622/06.01-Publishing_an_Experiment_via_MQTT.html#6.1.3-Version-1)
# * [6.2.2 Remote Operation of a Laboratory Experiment](https://jckantor.github.io/cbe61622/06.02-Accessing_a_Remote_Experiment_via_MQTT.html#6.2.2-Remote-Operation-of-a-Laboratory-Experiment)
# * [6.2.2 Remote Operation of a Laboratory Experiment](https://jckantor.github.io/cbe61622/06.02-Accessing_a_Remote_Experiment_via_MQTT.html#6.2.2-Remote-Operation-of-a-Laboratory-Experiment)
# * [6.2.3 Version 1](https://jckantor.github.io/cbe61622/06.02-Accessing_a_Remote_Experiment_via_MQTT.html#6.2.3-Version-1)
# * [6.2.3 Version 1](https://jckantor.github.io/cbe61622/06.02-Accessing_a_Remote_Experiment_via_MQTT.html#6.2.3-Version-1)
# * [6.3.3 Receiving data from Particle Argon device](https://jckantor.github.io/cbe61622/06.03-Miscellaneous_Notes.html#6.3.3-Receiving-data-from-Particle-Argon-device)
# * [6.3.3 Receiving data from Particle Argon device](https://jckantor.github.io/cbe61622/06.03-Miscellaneous_Notes.html#6.3.3-Receiving-data-from-Particle-Argon-device)
#
# ### picamera
# * [4.5.1 PiCamera](https://jckantor.github.io/cbe61622/04.05-rpi-picamera_test.html#4.5.1-PiCamera)
# * [4.5.1.1 Camera preview](https://jckantor.github.io/cbe61622/04.05-rpi-picamera_test.html#4.5.1.1-Camera-preview)
# * [4.5.1.1 Camera preview](https://jckantor.github.io/cbe61622/04.05-rpi-picamera_test.html#4.5.1.1-Camera-preview)
# * [4.5.1.2 Capture to stream and display](https://jckantor.github.io/cbe61622/04.05-rpi-picamera_test.html#4.5.1.2-Capture-to-stream-and-display)
# * [4.5.1.3 Camera Settings](https://jckantor.github.io/cbe61622/04.05-rpi-picamera_test.html#4.5.1.3-Camera-Settings)
# * [4.5.1.3 Camera Settings](https://jckantor.github.io/cbe61622/04.05-rpi-picamera_test.html#4.5.1.3-Camera-Settings)
# * [4.5.1.4 Capture to numpy array](https://jckantor.github.io/cbe61622/04.05-rpi-picamera_test.html#4.5.1.4-Capture-to-numpy-array)
# * [4.5.1.4 Capture to numpy array](https://jckantor.github.io/cbe61622/04.05-rpi-picamera_test.html#4.5.1.4-Capture-to-numpy-array)
#
# ### PIL
# * [4.5.1.2 Capture to stream and display](https://jckantor.github.io/cbe61622/04.05-rpi-picamera_test.html#4.5.1.2-Capture-to-stream-and-display)
# * [4.5.1.3 Camera Settings](https://jckantor.github.io/cbe61622/04.05-rpi-picamera_test.html#4.5.1.3-Camera-Settings)
#
# ### random
# * [3.11.2.1 Shot Noise](https://jckantor.github.io/cbe61622/03.11-Low-Level-Measurment.html#3.11.2.1-Shot-Noise)
#
# ### re
# * [2.1.3.3 Reading Grove Light Sensor V1.2](https://jckantor.github.io/cbe61622/02.01-Particle_CLI.html#2.1.3.3-Reading-Grove-Light-Sensor-V1.2)
# * [2.3.1.2 Utility functions](https://jckantor.github.io/cbe61622/02.03-Particle-CLI.html#2.3.1.2-Utility-functions)
# * [2.4.1.2 Utility functions](https://jckantor.github.io/cbe61622/02.04-Ultrasonic_Distance_Ranger.html#2.4.1.2-Utility-functions)
# * [2.5.1.2 Utility functions](https://jckantor.github.io/cbe61622/02.05-Simple_Stop_Watch_using_Interrupts.html#2.5.1.2-Utility-functions)
# * [9.1.1.2 Utility functions](https://jckantor.github.io/cbe61622/09.01-Communicating _via_TCP.html#9.1.1.2-Utility-functions)
# * [9.2.1.2 Utility functions](https://jckantor.github.io/cbe61622/09.02-Stepper_Motor_Control_via_I2C.html#9.2.1.2-Utility-functions)
#
# ### rp2
# * [3.8.4 Programmable Input/Ouput (PIO)](https://jckantor.github.io/cbe61622/03.08-Stepper-Motors.html#3.8.4-Programmable-Input/Ouput-(PIO))
# * [3.9.3 Interacting PIO programs](https://jckantor.github.io/cbe61622/03.09-PIO-Programming.html#3.9.3-Interacting-PIO-programs)
#
# ### simpy
# * [6.1.3 Version 1](https://jckantor.github.io/cbe61622/06.01-Publishing_an_Experiment_via_MQTT.html#6.1.3-Version-1)
# * [A.4.1 Blinkers](https://jckantor.github.io/cbe61622/A.04-Scheduling-Real-Time-Events-with-Simpy.html#A.4.1-Blinkers)
#
# ### subprocess
# * [2.1.2 Login to Particle](https://jckantor.github.io/cbe61622/02.01-Particle_CLI.html#2.1.2-Login-to-Particle)
# * [2.1.3.2 Toggle on-board led](https://jckantor.github.io/cbe61622/02.01-Particle_CLI.html#2.1.3.2-Toggle-on-board-led)
# * [2.1.3.3 Reading Grove Light Sensor V1.2](https://jckantor.github.io/cbe61622/02.01-Particle_CLI.html#2.1.3.3-Reading-Grove-Light-Sensor-V1.2)
# * [2.2.2 Login to Particle](https://jckantor.github.io/cbe61622/02.02-Particle_Coding.html#2.2.2-Login-to-Particle)
# * [2.3.1.2 Utility functions](https://jckantor.github.io/cbe61622/02.03-Particle-CLI.html#2.3.1.2-Utility-functions)
# * [2.4.1.2 Utility functions](https://jckantor.github.io/cbe61622/02.04-Ultrasonic_Distance_Ranger.html#2.4.1.2-Utility-functions)
# * [2.5.1.2 Utility functions](https://jckantor.github.io/cbe61622/02.05-Simple_Stop_Watch_using_Interrupts.html#2.5.1.2-Utility-functions)
# * [9.1.1.2 Utility functions](https://jckantor.github.io/cbe61622/09.01-Communicating _via_TCP.html#9.1.1.2-Utility-functions)
# * [9.2.1.2 Utility functions](https://jckantor.github.io/cbe61622/09.02-Stepper_Motor_Control_via_I2C.html#9.2.1.2-Utility-functions)
# * [A.2.1 Method 1. Downloading individual Python files with wget](https://jckantor.github.io/cbe61622/A.02-Downloading_Python_source_files_from_github.html#A.2.1-Method-1.-Downloading-individual-Python-files-with-wget)
#
# ### sys
# * [3.8.4 Programmable Input/Ouput (PIO)](https://jckantor.github.io/cbe61622/03.08-Stepper-Motors.html#3.8.4-Programmable-Input/Ouput-(PIO))
# * [3.8.4 Programmable Input/Ouput (PIO)](https://jckantor.github.io/cbe61622/03.08-Stepper-Motors.html#3.8.4-Programmable-Input/Ouput-(PIO))
# * [3.8.4 Programmable Input/Ouput (PIO)](https://jckantor.github.io/cbe61622/03.08-Stepper-Motors.html#3.8.4-Programmable-Input/Ouput-(PIO))
# * [A.2.2 Method 2. Cloning a git repository](https://jckantor.github.io/cbe61622/A.02-Downloading_Python_source_files_from_github.html#A.2.2-Method-2.-Cloning-a-git-repository)
# * [A.2.2 Method 2. Cloning a git repository](https://jckantor.github.io/cbe61622/A.02-Downloading_Python_source_files_from_github.html#A.2.2-Method-2.-Cloning-a-git-repository)
# * [A.2.2 Method 2. Cloning a git repository](https://jckantor.github.io/cbe61622/A.02-Downloading_Python_source_files_from_github.html#A.2.2-Method-2.-Cloning-a-git-repository)
#
# ### time
# * [2.1.3.2 Toggle on-board led](https://jckantor.github.io/cbe61622/02.01-Particle_CLI.html#2.1.3.2-Toggle-on-board-led)
# * [2.1.3.3 Reading Grove Light Sensor V1.2](https://jckantor.github.io/cbe61622/02.01-Particle_CLI.html#2.1.3.3-Reading-Grove-Light-Sensor-V1.2)
# * [3.1.3.1 Activity](https://jckantor.github.io/cbe61622/03.01-Getting_Started.html#3.1.3.1-Activity)
# * [3.3.3 A Simple Clock](https://jckantor.github.io/cbe61622/03.03-LCD1602.html#3.3.3-A-Simple-Clock)
# * [3.4 Managing Multiple Devices with an Event Loop](https://jckantor.github.io/cbe61622/03.04-Simple_Event_Loop.html#3.4-Managing-Multiple-Devices-with-an-Event-Loop)
# * [3.5.3 Single threaded, imperative coding](https://jckantor.github.io/cbe61622/03.05-Coding-Paradigms.html#3.5.3-Single-threaded,-imperative-coding)
# * [3.5.3 Single threaded, imperative coding](https://jckantor.github.io/cbe61622/03.05-Coding-Paradigms.html#3.5.3-Single-threaded,-imperative-coding)
# * [3.6.3 Single threaded, imperative coding](https://jckantor.github.io/cbe61622/03.06-Coding-Paradigms.html#3.6.3-Single-threaded,-imperative-coding)
# * [3.6.3 Single threaded, imperative coding](https://jckantor.github.io/cbe61622/03.06-Coding-Paradigms.html#3.6.3-Single-threaded,-imperative-coding)
# * [3.6.3 Single threaded, imperative coding](https://jckantor.github.io/cbe61622/03.06-Coding-Paradigms.html#3.6.3-Single-threaded,-imperative-coding)
# * [3.7.2.1 Polling](https://jckantor.github.io/cbe61622/03.07-Event-Driven-Programming.html#3.7.2.1-Polling)
# * [3.7.2.2 Timer](https://jckantor.github.io/cbe61622/03.07-Event-Driven-Programming.html#3.7.2.2-Timer)
# * [3.7.2.2 Timer](https://jckantor.github.io/cbe61622/03.07-Event-Driven-Programming.html#3.7.2.2-Timer)
# * [3.7.3 Interrupt Requests and Service Routines: IRQ/ISR](https://jckantor.github.io/cbe61622/03.07-Event-Driven-Programming.html#3.7.3-Interrupt-Requests-and-Service-Routines:-IRQ/ISR)
# * [3.7.3 Interrupt Requests and Service Routines: IRQ/ISR](https://jckantor.github.io/cbe61622/03.07-Event-Driven-Programming.html#3.7.3-Interrupt-Requests-and-Service-Routines:-IRQ/ISR)
# * [3.7.3.1 Capturing data via IRQ/ISR's](https://jckantor.github.io/cbe61622/03.07-Event-Driven-Programming.html#3.7.3.1-Capturing-data-via-IRQ/ISR's)
# * [3.8.3 Driving the 28BYJ-48 Stepper Motor](https://jckantor.github.io/cbe61622/03.08-Stepper-Motors.html#3.8.3-Driving-the-28BYJ-48-Stepper-Motor)
# * [3.8.4 Programmable Input/Ouput (PIO)](https://jckantor.github.io/cbe61622/03.08-Stepper-Motors.html#3.8.4-Programmable-Input/Ouput-(PIO))
# * [3.9.1 Setting multiple pins from Python](https://jckantor.github.io/cbe61622/03.09-PIO-Programming.html#3.9.1-Setting-multiple-pins-from-Python)
# * [3.9.2 Writing Stepper Steps to pins](https://jckantor.github.io/cbe61622/03.09-PIO-Programming.html#3.9.2-Writing-Stepper-Steps-to-pins)
# * [3.9.2 Writing Stepper Steps to pins](https://jckantor.github.io/cbe61622/03.09-PIO-Programming.html#3.9.2-Writing-Stepper-Steps-to-pins)
# * [3.9.2 Writing Stepper Steps to pins](https://jckantor.github.io/cbe61622/03.09-PIO-Programming.html#3.9.2-Writing-Stepper-Steps-to-pins)
# * [3.9.3 Interacting PIO programs](https://jckantor.github.io/cbe61622/03.09-PIO-Programming.html#3.9.3-Interacting-PIO-programs)
# * [3.9.3 Interacting PIO programs](https://jckantor.github.io/cbe61622/03.09-PIO-Programming.html#3.9.3-Interacting-PIO-programs)
# * [3.10.1 ESP01 class](https://jckantor.github.io/cbe61622/03.10-Wifi-with-ESP-01.html#3.10.1-ESP01-class)
# * [4.5.1.1 Camera preview](https://jckantor.github.io/cbe61622/04.05-rpi-picamera_test.html#4.5.1.1-Camera-preview)
# * [4.5.1.1 Camera preview](https://jckantor.github.io/cbe61622/04.05-rpi-picamera_test.html#4.5.1.1-Camera-preview)
# * [4.5.1.2 Capture to stream and display](https://jckantor.github.io/cbe61622/04.05-rpi-picamera_test.html#4.5.1.2-Capture-to-stream-and-display)
# * [4.5.1.3 Camera Settings](https://jckantor.github.io/cbe61622/04.05-rpi-picamera_test.html#4.5.1.3-Camera-Settings)
# * [4.5.1.3 Camera Settings](https://jckantor.github.io/cbe61622/04.05-rpi-picamera_test.html#4.5.1.3-Camera-Settings)
# * [4.5.1.4 Capture to numpy array](https://jckantor.github.io/cbe61622/04.05-rpi-picamera_test.html#4.5.1.4-Capture-to-numpy-array)
# * [4.5.1.4 Capture to numpy array](https://jckantor.github.io/cbe61622/04.05-rpi-picamera_test.html#4.5.1.4-Capture-to-numpy-array)
# * [6.1.2.1 Proof of Concept](https://jckantor.github.io/cbe61622/06.01-Publishing_an_Experiment_via_MQTT.html#6.1.2.1-Proof-of-Concept)
# * [6.1.3 Version 1](https://jckantor.github.io/cbe61622/06.01-Publishing_an_Experiment_via_MQTT.html#6.1.3-Version-1)
# * [6.2.2 Remote Operation of a Laboratory Experiment](https://jckantor.github.io/cbe61622/06.02-Accessing_a_Remote_Experiment_via_MQTT.html#6.2.2-Remote-Operation-of-a-Laboratory-Experiment)
# * [6.2.3 Version 1](https://jckantor.github.io/cbe61622/06.02-Accessing_a_Remote_Experiment_via_MQTT.html#6.2.3-Version-1)
# * [6.3.3 Receiving data from Particle Argon device](https://jckantor.github.io/cbe61622/06.03-Miscellaneous_Notes.html#6.3.3-Receiving-data-from-Particle-Argon-device)
# * [A.3.3 Blinker](https://jckantor.github.io/cbe61622/A.03-Getting-Started-with-Pymata4.html#A.3.3-Blinker)
# * [A.3.4 Handling a Keyboard Interrupt](https://jckantor.github.io/cbe61622/A.03-Getting-Started-with-Pymata4.html#A.3.4-Handling-a-Keyboard-Interrupt)
# * [A.3.5 Getting Information about the Arduino](https://jckantor.github.io/cbe61622/A.03-Getting-Started-with-Pymata4.html#A.3.5-Getting-Information-about-the-Arduino)
# * [A.3.6 Temperature Control Lab Shield](https://jckantor.github.io/cbe61622/A.03-Getting-Started-with-Pymata4.html#A.3.6-Temperature-Control-Lab-Shield)
# * [A.4.1 Blinkers](https://jckantor.github.io/cbe61622/A.04-Scheduling-Real-Time-Events-with-Simpy.html#A.4.1-Blinkers)
# * [A.4.2 Asyncio](https://jckantor.github.io/cbe61622/A.04-Scheduling-Real-Time-Events-with-Simpy.html#A.4.2-Asyncio)
#
# ### urllib
# * [A.2.2.1 Commit and push changes](https://jckantor.github.io/cbe61622/A.02-Downloading_Python_source_files_from_github.html#A.2.2.1-Commit-and-push-changes)
#
# ### uuid
# * [6.2.2 Remote Operation of a Laboratory Experiment](https://jckantor.github.io/cbe61622/06.02-Accessing_a_Remote_Experiment_via_MQTT.html#6.2.2-Remote-Operation-of-a-Laboratory-Experiment)
